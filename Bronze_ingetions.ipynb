# %%
df = spark.read.format("csv").option("header","true").option("inferSchema","true").load("/Volumes/transportation/raw/city/city.csv")

# %%
df.write.mode("overwrite").saveAsTable("workspace.gold.raw_customers")

# %%
df1= spark.table("workspace.bronze.raw_customers")

# %%
df1.write.mode("overwrite").saveAsTable("workspace.silver.rammm")
